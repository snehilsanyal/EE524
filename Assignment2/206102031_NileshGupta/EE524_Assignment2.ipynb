# %% [markdown]
# <a href="https://colab.research.google.com/github/Bluelord/EE524/blob/assignments/Assignment2/206102031_NileshGupta/EE524_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EE524 Introduction to Machine Learning Lab**

# %% [markdown]
# ## **Assignment 2**

# %% [markdown]
# Name: **Gupta Nilesh**, Ph.D. EEE Department.
#
# Roll No. **206102031**

# %% [markdown]
# ### **Answe 1.**

# %%
import numpy as np
from matplotlib import pyplot as plt
# (a)
a,b = 2,3
# (b)
x = np.linspace(-10, 10, 100)
# (c)
y = a*x +b
# (d)
plt.plot(x,y, 'k')
plt.show()

# %%
# (e)
sigma = 1 #std can be changed to observe the variaton in plot
noise = np.random.normal(0, sigma, x.size)
z = a*x + b + noise
# (f)
plt.figure(figsize=(9,7))
plt.plot(x,y, 'k')
plt.scatter(x,z, s = 5, c ='r' )
plt.show()

# %% [markdown]
# **Answer 2.**

# %%
a = np.arange(-10, 10, 0.1)
b = np.arange(-10, 10, 0.1)
E = np.empty((len(a),len(b)), dtype=float)

#(a) loop for considering all the combination of a,b
for i in range(len(a)):
  for j in range(len(b)):
    y = a[i]*x+b[j]
    #(b) Error btw the noisy z line and selected possible y line
    error = z - y
    sum = 0
    #(c) Loop through the array  to calculate Mean square error   
    for k in range(0, len(error)):
      E[i][j] = E[i][j] + ((error[k])*(error[k]))
    #(d) Stores all the possible MSE for different a,b values 
    E[i][j] = E[i][j]/len(error)

# %%
#(e) ploting 
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1, 1, 1, projection='3d')

x = np.linspace(-10, 10,200)
y = np.linspace(-10, 10,200)
Z = E
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.coolwarm,linewidth=0, antialiased=False)
fig.colorbar(surf)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()
