# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import math

# %matplotlib inline

# %% [markdown]
# # QUESTION NO. 1

# %% [markdown]
# ## Question 1.a

# %%
a = 2
b = 3
print("Value of a is :", a)
print("Value of b is :", b)
# Out:
# Value of a is : 2
# Value of b is : 3

# %% [markdown]
# ## Question 1.b

# %%
# Generating Array x
x = np.linspace(start = -10, stop = 10 ,num = 100, endpoint = True)
print("Array x is:\n",x)
# Out:
# Array x is:
#  [-10.          -9.7979798   -9.5959596   -9.39393939  -9.19191919
#   -8.98989899  -8.78787879  -8.58585859  -8.38383838  -8.18181818
#   -7.97979798  -7.77777778  -7.57575758  -7.37373737  -7.17171717
#   -6.96969697  -6.76767677  -6.56565657  -6.36363636  -6.16161616
#   -5.95959596  -5.75757576  -5.55555556  -5.35353535  -5.15151515
#   -4.94949495  -4.74747475  -4.54545455  -4.34343434  -4.14141414
#   -3.93939394  -3.73737374  -3.53535354  -3.33333333  -3.13131313
#   -2.92929293  -2.72727273  -2.52525253  -2.32323232  -2.12121212
#   -1.91919192  -1.71717172  -1.51515152  -1.31313131  -1.11111111
#   -0.90909091  -0.70707071  -0.50505051  -0.3030303   -0.1010101
#    0.1010101    0.3030303    0.50505051   0.70707071   0.90909091
#    1.11111111   1.31313131   1.51515152   1.71717172   1.91919192
#    2.12121212   2.32323232   2.52525253   2.72727273   2.92929293
#    3.13131313   3.33333333   3.53535354   3.73737374   3.93939394
# ...

# %% [markdown]
# ## Question 1.c

# %%
# Computing y array
y = a*x + b
print("Array y is:\n",y)
# Out:
# Array y is:
#  [-17.         -16.5959596  -16.19191919 -15.78787879 -15.38383838
#  -14.97979798 -14.57575758 -14.17171717 -13.76767677 -13.36363636
#  -12.95959596 -12.55555556 -12.15151515 -11.74747475 -11.34343434
#  -10.93939394 -10.53535354 -10.13131313  -9.72727273  -9.32323232
#   -8.91919192  -8.51515152  -8.11111111  -7.70707071  -7.3030303
#   -6.8989899   -6.49494949  -6.09090909  -5.68686869  -5.28282828
#   -4.87878788  -4.47474747  -4.07070707  -3.66666667  -3.26262626
#   -2.85858586  -2.45454545  -2.05050505  -1.64646465  -1.24242424
#   -0.83838384  -0.43434343  -0.03030303   0.37373737   0.77777778
#    1.18181818   1.58585859   1.98989899   2.39393939   2.7979798
#    3.2020202    3.60606061   4.01010101   4.41414141   4.81818182
#    5.22222222   5.62626263   6.03030303   6.43434343   6.83838384
#    7.24242424   7.64646465   8.05050505   8.45454545   8.85858586
#    9.26262626   9.66666667  10.07070707  10.47474747  10.87878788
# ...

# %% [markdown]
# ## Question 1.d

# %%
# Line plot using matplotlib in black colour
plt.plot(x,y,'k');

# %% [markdown]
# ## Question 1.e

# %%
# Generating n points with variance

# Compute standard deviation of y
# sigma = np.std(y)
# print("Sigma of y is: \n", sigma)

# Creating normal distribution
#when sigma is taking as 1
sigma=1
N = np.random.normal(0, 1 , size = 100)

# Generating n points
y1 = y + sigma*N
print("y1 array after adding normal distribution is :\n", y1)
# Out:
# y1 array after adding normal distribution is :
#  [-17.40660663 -16.57773686 -16.36979226 -16.77760818 -15.22888044
#  -15.17372375 -15.80633659 -13.51848568 -13.4249975  -12.92220847
#  -12.90383341 -12.55821852 -11.74913027 -12.72120095 -11.15004891
#  -10.8398849  -10.03775517  -9.54882921  -8.66309227  -9.77270689
#   -6.96572039  -8.22427992  -8.35067584  -6.99345446  -6.55169848
#   -7.62351697  -6.88942153  -6.45529282  -5.43414524  -6.40585575
#   -3.99932611  -4.65838156  -4.85761321  -5.4667806   -5.07856728
#   -2.32561391  -2.60634824  -2.09606358  -1.87476374  -1.23898709
#   -2.9705774    0.35126072  -0.31953918   1.06956046   0.68437486
#    2.39118437   2.44657877   2.39070473   2.31763006   1.45177226
#    2.36514001   2.26505721   3.22931184   4.55714417   5.40062175
#    4.61193392   5.25332253   6.34367887   5.00468664   6.89106172
#    5.68514303   7.50670867   9.23207476   8.89807056   8.92252683
# ...

# %% [markdown]
# ## Question 1.f

# %%
# Plotting line graph
plt.plot(x,y, 'k')

# Plotting scatter plot on same graph
plt.scatter(x, y1, color = 'r');

# %% [markdown]
# # QUESTION NO. 2

# %% [markdown]
# ## Question 2.a

# %%
#assign diiferent value to a and b in range
a2=np.arange(start=-10,stop = 10, step =0.1) 
b2=np.arange(start=-10,stop = 10, step =0.1)

# %% [markdown]
# ## Question 2.b

# %%
# Defined the function for element error and average error
def ele_err(a,b):
    y2 = a*x+b
    e1 = y1-y2
    E = sum(e1**2)/100
    return E, e1

# %%
# Computing element error for random value for a and b
com_error = ele_err(a,b)[1]
print("computed element error is :\n",com_error)
# Out:
# computed element error is :
#  [-0.40660663  0.01822274 -0.17787307 -0.98972939  0.15495794 -0.19392577
#  -1.23057901  0.6532315   0.34267927  0.44142789  0.05576255 -0.00266297
#   0.40238488 -0.9737262   0.19338543  0.09950904  0.49759836  0.58248392
#   1.06418046 -0.44947456  1.95347153  0.29087159 -0.23956472  0.71361625
#   0.75133182 -0.72452707 -0.39447204 -0.36438373  0.25272345 -1.12302747
#   0.87946177 -0.18363408 -0.78690614 -1.80011393 -1.81594101  0.53297195
#  -0.15180278 -0.04555853 -0.2282991   0.00343715 -2.13219356  0.78560415
#  -0.28923615  0.69582309 -0.09340292  1.20936618  0.86072018  0.40080574
#  -0.07630933 -1.34620754 -0.83688019 -1.3410034  -0.78078917  0.14300276
#   0.58243993 -0.6102883  -0.3729401   0.31337584 -1.4296568   0.05267788
#  -1.55728121 -0.13975597  1.18156971  0.44352511  0.06394098 -1.95069525
#  -0.10023468 -1.2419228  -0.64250023 -0.71547023 -0.3101444   1.89228972
# ...

# %% [markdown]
# ## Question 2.c

# %%
# computing average error for random value of a and b
avg_error = ele_err(a,b)[0]
print("average error for random value of a and b is : \n",avg_error)
# Out:
# average error for random value of a and b is :
#  0.7731223772559801

# %% [markdown]
# ## Question 2.d

# %%
# Avg Error for all combination of a and b
error = []
x_plot = []
y_plot = []
for i in range(len(a2)):
    for j in range(len(b2)):
        err = ele_err(a2[i],b2[j])[0]
        x_plot.append(a2[i])
        y_plot.append(b2[j])
        error.append(err)
print("Average error for all combination of a and b is : \n", error)
# Out:
# Average error for all combination of a and b is :
# ...

# %% [markdown]
# ## Question 2.e

# %%
# 3d plot for average error 
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_plot, y_plot, error, c = error);
