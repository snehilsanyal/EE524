# %%
# Question 1
import random
import matplotlib.pyplot as plt
import numpy as np 

a,b = 2,3

x = np.linspace(-10,10,100)
y = a*x + b

s=np.std(x)

y1 = np.random.normal(0,1,100)
y2 = y + s*y1
plt.ylim(-20,30)
plt.plot(x,y,color = 'k',linewidth = 3)


plt.scatter(x, y2, c='red',label = 'noise')
plt.legend()
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# Question 2 (tried)
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random

def fun(x, y):
    x = np.linspace(-10,10,200)
    y = a*x + b
    s=np.std(x)

    y1 = np.random.normal(200)
    y2 = y + s*y1
    error = y2-y
    sse = np.sum(error**2)
    R= (sse.mean())
    return R
    

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
a = b = np.arange(-10 , 10 , 0.1)
X, Y = np.meshgrid(a, b)
zs = np.array([fun(a,b) for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
# Question 2 (tried)
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random

x = np.linspace(-10,10,200)
a = b = np.arange(-10 , 10 , 0.1)
y = a*x + b
s=np.std(x)

y1 = np.random.normal(200)
y2 = y + s*y1

e = y2 - y 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')



err = np.sum(e**2)/100

error = np.array([100])

for i in a:
    for j in b:
        
        y=i*x + b 
        y1 = y  + np.random.rand(200)
        e = y - y1
        err1 =  sum(e**2)/100
        error = np.append(error ,err1)

        
error = error.reshape(200,200)
a , b = np.meshgrid(a, b)        
ax.plot_surface(a,b,error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-980a32c71f54> in <module>
#      33
#      34
# ---> 35 error = error.reshape(200,201)
#      36 a , b = np.meshgrid(a, b)
#      37 ax.plot_surface(a,b,error)
#
# ValueError: cannot reshape array of size 40001 into shape (200,201)
