# %% [markdown]
# # * ASSIGNMENT - 2 *

# %% [markdown]
# # 1. Generate a set of points around a line y = ax + b

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
a = 2
b = 3
x=np.linspace(-10,10,100)
y=[a*x[i]+b for i in range(100)]
plt.plot(x,y,c='black')
plt.xlim(-10,10)
s=np.std(x)
u=np.random.normal(0,1,100)
z=(y)+(s)*(u)
plt.scatter(x,z,c='red')
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.title('Y=AX+B')
plt.show()

# %% [markdown]
# # 2.Plot the average error surface E for different values of a and b

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random
import numpy as np

a=np.arange(-10, 10, 0.1)
b=np.arange(-10, 10, 0.1)
X=np.arange(-10, 10, 0.1)

s=np.std(X)
N=np.var(s)
u=np.random.normal(0,1,200)
Y=2*X+3+(N)*(u)

n=100

for i in range(0,200):
    E1=((Y-a*X[i]+b)**2)
    i+=1
    E2=E1/n 
    
fig = plt.figure()
ax=fig.gca(projection='3d')

a, b = np.meshgrid(a, b)
E2 = np.array([E1 for X,Y in zip(np.ravel(X), np.ravel(Y))])
E = E2.reshape(a.shape)

ax.plot_surface(a, b, E,cmap='plasma')

ax.set_xlabel('X-AXIS')
ax.set_ylabel('Y-AXIS')
ax.set_zlabel('ERROR')
# Out:
# Text(0.5, 0, 'ERROR')
