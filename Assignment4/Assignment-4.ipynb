# %% [markdown]
# ##### Q.1. (a). Let us consider x to be a random variable, where x belong to[-10,10]. Gen-erate 100 samples of x and plot the pdf of x for x~ N(0; 1) and x~N(3; 2).Comment on the difference in plot. If there is a difference in magnitude, comment why?
# #### (b). Consider the two-dimensional normal distribution p(x|w) N(mue; sigma)where mue =[0,0]T and sigma =[[1 .6]:[.6 2]].Let x be a random vector denoted by x =[x1 x2], where xi=[-10,10]. Plot the surface plot and counter plot of the pdf?

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook
import math 
import random

#gerating sequence for x axis
x=np.linspace(-10,10,100)

#genrating first normal RV
mue_1=0
sig_1=1
var_1=sig_1**2
Y_1=(1/(2*math.pi*var_1)**.5)*((math.e)**-(((x-mue_1)*1/sig_1)**2))
plt.scatter(x,Y_1)

##genrating second normal RV
mue_2=3
sig_2=2
var_2=(sig_2)**2
Y_2=(1/(2*math.pi*var_2)**.5)*((math.e)**-(((x-mue_2)*1/sig_2)**2))
plt.scatter(x,Y_2)


#REASONING FOR MAGNITUDE DIFFERENCE
#magnitude is being governed by the variance alone whihc is diffenent for both of them
max_mag_1=1/(2*math.pi*var_1)**.5
print("maximum magnitudeof 1st pdf is",max_mag_1)
max_mag_2=1/(2*math.pi*var_2)**.5
print("maximum magnitudeof 2nd pdf is",max_mag_2)
diff_mag=max_mag_1-max_mag_2
print("difference in magnitude",diff_mag)
# Out:
# <img src="data:image/png;base64,..." width="640">
# maximum magnitudeof 1st pdf is 0.3989422804014327
# maximum magnitudeof 2nd pdf is 0.19947114020071635
# difference in magnitude 0.19947114020071635

# %% [markdown]
# (b). Consider the two-dimensional normal distribution p(x|w) N(mue; sigma)where mue =[0,0]T and sigma =[[1 .6]:[.6 2]].Let x be a random vector denoted by x =[x1 x2], where xi=[-10,10]. Plot the surface plot and counter plot of the pdf?

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook
import random 
import math 


a=np.linspace(-10,10,100)
b=np.linspace(-10,10,100)
X,Y=np.meshgrid(a,b)

fig=plt.figure(figsize=(50,50))
ax1=fig.add_subplot(projection="3d")
ax2=fig.add_subplot(projection="3d")

#gerating sequence for x axis

arr=np.array([a,b])
mue=np.array([[0],[0]])
sigma=np.array([[1,0.6],[.6,2]])
sigma
def gauss_2d(mue, sigma):
    x = random.gauss(mue, sigma)
    y = random.gauss(mue, sigma)
    return (x, y)

G=gauss_2d(arr,mue)
plt.scatter
# Out:
# <img src="data:image/png;base64,..." width="5000">
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=<deprecated parameter>, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)>

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

#reading a CSV file
attributes=["sepal_length","sepal_width","petal_length","petal_width","species"]
iris=pd.read_csv('iris.data',names=attributes)
print(iris.shape)
x=iris["species"].value_counts()
print(x)



#plotting unsorted 

iris.plot(kind='scatter',x="sepal_length", y="sepal_width")
plt.legend("species")
plt.show()
# Out:
# (150, 5)
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: species, dtype: int64
# <img src="data:image/png;base64,..." width="640">

# %%
#sorting the dataset
iris_sort=iris.sort_values("species",axis=0)
iris_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 27            5.2          3.5           1.5          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# 30            4.8          3.1           1.6          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 119           6.0          2.2           5.0          1.5  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#preparing training dataset
x=iris_sort.iloc[:,:-1]
print(x)
y=iris_sort.iloc[:,-1]
print(y)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 27            5.2          3.5           1.5          0.2
# 28            5.2          3.4           1.4          0.2
# 29            4.7          3.2           1.6          0.2
# 30            4.8          3.1           1.6          0.2
# ..            ...          ...           ...          ...
# 119           6.0          2.2           5.0          1.5
# 120           6.9          3.2           5.7          2.3
# 121           5.6          2.8           4.9          2.0
# 111           6.4          2.7           5.3          1.9
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
# 0         Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
# 30        Iris-setosa
#             ...
# 119    Iris-virginica
# 120    Iris-virginica
# 121    Iris-virginica
# 111    Iris-virginica
# ...

# %%
X=iris_sort.drop(columns=["species"])
Y=iris_sort["species"]
#spliting the  data as per the ratioa given
train_x,test_x=train_test_split(X,test_size=0.3)
train_y,test_y=train_test_split(Y,test_size=0.3)

print(train_x)
print(train_y)
print(test_x)
print(test_y)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 41            4.5          2.3           1.3          0.3
# 7             5.0          3.4           1.5          0.2
# 63            6.1          2.9           4.7          1.4
# 147           6.5          3.0           5.2          2.0
# 26            5.0          3.4           1.6          0.4
# ..            ...          ...           ...          ...
# 142           5.8          2.7           5.1          1.9
# 56            6.3          3.3           4.7          1.6
# 54            6.5          2.8           4.6          1.5
# 40            5.0          3.5           1.3          0.3
# 8             4.4          2.9           1.4          0.2
#
# [105 rows x 4 columns]
# 87     Iris-versicolor
# 142     Iris-virginica
# 98     Iris-versicolor
# 139     Iris-virginica
# 8          Iris-setosa
#             ...
# 96     Iris-versicolor
# 44         Iris-setosa
# 55     Iris-versicolor
# 15         Iris-setosa
# ...

# %%
#model training
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(test_x,test_y)*100)
# Out:
# Accuracy: 31.11111111111111
