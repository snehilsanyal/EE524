# %%
#QUESTION 1 (A)


import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sci
import math
from mpl_toolkits.mplot3d import Axes3D 
 

fig = plt.figure()

ax1 = fig.add_subplot(121)
mu = 0
variance = 1
sigma = np.sqrt(variance)
x = np.linspace(mu - 10*sigma, mu + 10*sigma, 100)
ax1.plot(x, sci.norm.pdf(x, mu, sigma))

ax2 = fig.add_subplot(122)
mu = 3
variance = 2
sigma = np.sqrt(variance)
x = np.linspace(mu - 10*sigma, mu + 6*sigma, 100)
ax2.plot(x, sci.norm.pdf(x, mu, sigma))
plt.show()

plt.tight_layout()

#As we can see the second plot is shifted towards right because now mean is 3 , also due to change in sigma values of two plots
#,we can observe change in magnitude values for the two plots

# %%
#QUESTION 1 (B)


import matplotlib.pyplot as plt
import numpy as np

d = 2 #dimension
mean = np.matrix([[0.], [0.]])
covariance = np.matrix([[1, 0.6], [0.6, 1]])


L = np.linalg.cholesky(covariance)# linear algebra library , which does cholesky[LU] decomposition and returns the triangular matrix
 
    

n = 100  
X = np.random.normal(size=(d, n))

Y = L.dot(X) + mean


def surface(mean, covariance, d):# function to generate pdf
    x1 = np.linspace(-5, 5, 100)
    x2 = np.linspace(-5, 5, 100)
    x1, x2 = np.meshgrid(x1, x2) # Generate grid
    pdf = np.zeros((100, 100))
    # Calculate the combinations and substitute in matrix
    for i in range(100):
        for j in range(100):
            pdf[i,j] = multivariatenormal(np.matrix([[x1[i,j]], [x2[i,j]]]), d, mean, covariance)
    return x1, x2, pdf  # x1, x2, pdf(x1,x2)

def multivariatenormal(x, d, mean, covariance):
    x = x - mean
    # x is a random vector of size d and we have positive definite covariance matrix and we have determinant of covariance matrix
    return (1. / (np.sqrt((2 * np.pi)**d * np.linalg.det(covariance))) * np.exp(-(np.linalg.solve(covariance, x).T.dot(x)) / 2)) 
    # this is the expression of multivariate distribution and returns it's values


fig, ax = plt.subplots(figsize=(6, 4.5))
# Plot bivariate distribution
x1, x2, p = surface(mean, covariance, d)
con = ax.contourf(x1, x2, p, 100, cmap='rainbow')
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_title('Bivariate normal distribution')
plt.show()

# %%
#Importing all libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score


iris = pd.read_csv(r'C:\Users\dell\Downloads/iris.data',header=None)
iris.columns=[ 'sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm','Class']#Giving names to each feature vector
pd.plotting.parallel_coordinates(iris, 'Class', color=['#556270', '#4ECDC4', '#C7F464'])

#Seperating dependent and indepenent variables
X = iris.iloc[:,:4].values
y = iris['Class'].values


#Splitting into training and testing samples and taking training samples as 70%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)


# Feature Scaling to bring the variable in a single scale
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#Using the bayes classifier and fitting data into that
classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)


#Displaying actual and predicted values side by side
y_compare = np.vstack((y_test,y_pred)).T
k = y_compare[:,:]
print(k)

#Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print('\n\n Confusion matrix is:',cm)

#Displaying the accuracy of the classifier build
print('\n\naccuracy is',accuracy_score(y_pred,y_test))
# Out:
# [['Iris-virginica' 'Iris-versicolor']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-virginica']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-virginica' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-setosa' 'Iris-setosa']
# ...
