# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


iris = pd.read_csv(r'C:\Users\dell\Downloads/iris.data',header=None)
iris.columns=[ 'sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm','Class']
X = iris.iloc[:, :-1].values
y = iris.iloc[:, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))


from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-setosa' 'Iris-setosa']
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


iris = pd.read_csv(r'C:\Users\dell\Downloads/iris.data',header=None)
iris.columns=[ 'sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm','Class']
X = iris.iloc[:, :-1].values
y = iris.iloc[:, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))


from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-versicolor' 'Iris-versicolor']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-setosa' 'Iris-setosa']
#  ['Iris-virginica' 'Iris-virginica']
#  ['Iris-setosa' 'Iris-setosa']
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import linalg as LA


iris = pd.read_csv(r'C:\Users\dell\Downloads/iris.data',header=None)
iris.columns=[ 'sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm','Species']


ax = iris[iris.Species=='Iris-setosa'].plot.scatter(x='sepal length in cm', y='sepal width in cm',color='red', label='setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='sepal length in cm', y='sepal width in cm', color='green', label='versicolor', ax=ax)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='sepal length in cm', y='sepal width in cm', color='blue', label='virginica', ax=ax)
ax.set_title("scatter")


ax = iris[iris.Species=='Iris-setosa'].plot.scatter(x='sepal length in cm', y='petal length in cm', color='red', label='setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='sepal length in cm', y='petal length in cm', color='green', label='versicolor', ax=ax)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='sepal length in cm', y='petal length in cm',color='blue', label='virginica', ax=ax)
ax.set_title("scatter")


ax = iris[iris.Species=='Iris-setosa'].plot.scatter(x='sepal length in cm', y='petal width in cm', color='red', label='setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='sepal length in cm', y='petal width in cm', color='green', label='versicolor', ax=ax)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='sepal length in cm', y='petal width in cm', color='blue', label='virginica', ax=ax)
ax.set_title("scatter")


ax = iris[iris.Species=='Iris-setosa'].plot.scatter(x='sepal width in cm', y='sepal width in cm', color='red', label='setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='sepal width in cm', y='sepal width in cm',color='green', label='versicolor', ax=ax)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='sepal width in cm', y='sepal width in cm', color='blue', label='virginica', ax=ax)
ax.set_title("scatter")


ax = iris[iris.Species=='Iris-setosa'].plot.scatter(x='sepal width in cm', y='petal width in cm', color='red', label='setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='sepal width in cm', y='petal width in cm', color='green', label='versicolor', ax=ax)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='sepal width in cm', y='petal width in cm', color='blue', label='virginica', ax=ax)
ax.set_title("scatter")


ax = iris[iris.Species=='Iris-setosa'].plot.scatter(x='petal length in cm', y='petal width in cm', color='red', label='setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='petal length in cm', y='petal width in cm', color='green', label='versicolor', ax=ax)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='petal length in cm', y='petal width in cm', color='blue', label='virginica', ax=ax)
ax.set_title("scatter")



iris["sepal length in cm"] = (iris["sepal length in cm"] - iris["sepal length in cm"].min())/(iris["sepal length in cm"].max() - iris["sepal length in cm"].min())
iris["sepal width in cm"] = (iris["sepal width in cm"] - iris["sepal width in cm"].min())/(iris["sepal width in cm"].max() - iris["sepal width in cm"].min())
iris["petal length in cm"] = (iris["petal length in cm"] - iris["petal length in cm"].min())/(iris["petal length in cm"].max() - iris["petal length in cm"].min())
iris["petal width in cm"] = (iris["petal width in cm"] - iris["petal width in cm"].min())/(iris["petal width in cm"].max() - iris["petal width in cm"].min())


iris1 = iris.drop(['Species'],axis = 1)
iris2 = iris1.to_numpy()
Fmean = np.mean(iris2,axis = 0)
F1mean = Fmean[0]
F2mean = Fmean[1]
F3mean = Fmean[2]
F4mean = Fmean[3]
mean = Fmean[0:4]
print('Mean vector is :' ,mean.reshape(4,1))
Covmatrix = pd.DataFrame.cov(iris)
print(Covmatrix)



eigen_values , eigen_vectors = LA.eig(Covmatrix)
print(eigen_values)
print(eigen_vectors)
     

sorted_index = np.sort(eigen_values)[::-1]
print(sorted_index)
eigenvector_subset = sorted_index[0:2]
P = eigen_vectors[:,0:2]
print(eigenvector_subset)
print(P)


X =iris[['sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm']]
Y = np.dot(X,P)


y=iris.iloc[:, -1].values
column_values = ['PC1', 'PC2'] 
df = pd.DataFrame(data = Y,   columns = column_values) 
df.insert(2, 'Species', y)
print(df)




ax = df[df.Species=='Iris-setosa'].plot.scatter(x='PC1', y='PC2', color='red', label='setosa')
df[df.Species=='Iris-versicolor'].plot.scatter(x='PC1', y='PC2', color='green', label='versicolor', ax=ax)
df[df.Species=='Iris-virginica'].plot.scatter(x='PC1', y='PC2',  color='blue', label='virginica', ax=ax)
ax.set_title("scatter")
# Out:
# Mean vector is : [[0.4287037 ]
#  [0.43916667]
#  [0.46757062]
#  [0.45777778]]
#                     sepal length in cm  sepal width in cm  petal length in cm  \
# sepal length in cm            0.052908          -0.004545            0.059966
# sepal width in cm            -0.004545           0.032640           -0.022720
# petal length in cm            0.059966          -0.022720            0.089433
# petal width in cm             0.059827          -0.020483            0.091553
#
#                     petal width in cm
# sepal length in cm           0.059827
# sepal width in cm           -0.020483
# petal length in cm           0.091553
# petal width in cm            0.101114
# [0.23231168 0.03239279 0.00963728 0.00175337]
# [[ 0.4252893  -0.42100611 -0.71434339  0.36276216]
#  [-0.14612219 -0.90470509  0.33510219 -0.21877734]
#  [ 0.61610511  0.06432645 -0.06825927 -0.78205964]
#  [ 0.64667752  0.01116485  0.61054133  0.45708076]]
# [0.23231168 0.03239279 0.00963728 0.00175337]
# ...
