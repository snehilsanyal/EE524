# %% [markdown]
# # K NEAREST NEIGHBOUR ALGORITHM without in built functions

# %%
import numpy as np                         ## import libraries
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt


def euclidean_distance(x1, x2):                    ## compute the eucladian distance 
        return np.sqrt(np.sum((x1 - x2)**2))


class KNN:

    def __init__(self, k=3):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        y_pred = [self._predict(x) for x in X]
        return np.array(y_pred)

    def _predict(self, x):
       
        distances = [euclidean_distance(x, x_train) for x_train in self.X_train] # distances between x and that in the training set
        
        k_idx = np.argsort(distances)[:self.k]# Sort by distance and return indices of the first k neighbors
        
        k_neighbor_labels = [self.y_train[i] for i in k_idx] #Extract the labels of the k nearest neighbor training samples
        
        most_common = Counter(k_neighbor_labels).most_common(1) # return the most common class label
        
        return most_common[0][0]

    
df =pd.read_csv("DishonestInternetUsers.csv")  ## read datset 
X = df.iloc[:,0:4].values
y = df.iloc[:,4].values

    
    
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)  ## split into train set and test set


def accuracy(y_true, y_pred):                              ## accuracy test
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy





print('\\n', X_train.shape)    # Inspect data
print('\\n', X_train[0])

print('\\n', y_train.shape)
print('\\n', y_train)


k = 5
clf = KNN(5)
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
print("custom KNN classification accuracy", accuracy(y_test, predictions))
# Out:
# \n (257, 4)
# \n [  1   1   1 400]
# \n (257,)
# \n ['trustworthy' 'trustworthy' 'trustworthy' 'trustworthy' 'trustworthy'
#  'untrustworthy' 'trustworthy' 'trustworthy' 'trustworthy' 'trustworthy'
#  'trustworthy' 'trustworthy' 'trustworthy' 'trustworthy' 'untrustworthy'
#  'trustworthy' 'trustworthy' 'trustworthy' 'trustworthy' 'trustworthy'
#  'trustworthy' 'trustworthy' 'untrustworthy' 'untrustworthy'
#  'untrustworthy' 'trustworthy' 'trustworthy' 'trustworthy' 'trustworthy'
#  'trustworthy' 'untrustworthy' 'trustworthy' 'untrustworthy'
#  'untrustworthy' 'untrustworthy' 'untrustworthy' 'trustworthy'
#  'trustworthy' 'trustworthy' 'trustworthy' 'untrustworthy' 'untrustworthy'
#  'trustworthy' 'untrustworthy' 'trustworthy' 'untrustworthy' 'trustworthy'
#  'trustworthy' 'trustworthy' 'trustworthy' 'untrustworthy' 'untrustworthy'
#  'untrustworthy' 'untrustworthy' 'untrustworthy' 'untrustworthy'
#  'trustworthy' 'trustworthy' 'untrustworthy' 'trustworthy' 'trustworthy'
# ...
